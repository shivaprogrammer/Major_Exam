# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.17.2-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.17.2 (from mlflow)
#   Downloading mlflow_skinny-2.17.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (3.0.3)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (3.8.4)
# Requirement already satisfied: numpy<3 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: scikit-learn<2 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (1.4.2)
# Requirement already satisfied: scipy<2 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (2.0.30)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow) (3.1.4)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (2.2.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.2->mlflow)
#   Downloading databricks_sdk-0.36.0-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (3.1.37)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (7.0.1)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow)
#   Downloading opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow)
#   Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<25 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (23.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (3.20.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\tiwar\anaconda3\lib\site-packages (from mlflow-skinny==2.17.2->mlflow) (2.32.2)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.17.2->mlflow)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\tiwar\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.11.0)
# Requirement already satisfied: pywin32>=304 in c:\users\tiwar\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\tiwar\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.2.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\tiwar\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\tiwar\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\tiwar\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.6.2)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.5-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\tiwar\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tiwar\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiwar\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiwar\anaconda3\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tiwar\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tiwar\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tiwar\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\tiwar\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.1)
# Requirement already satisfied: colorama in c:\users\tiwar\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.17.2->mlflow) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tiwar\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\tiwar\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.2->mlflow) (3.17.0)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\tiwar\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tiwar\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tiwar\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tiwar\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow) (2024.7.4)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\tiwar\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\tiwar\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tiwar\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tiwar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow) (0.4.8)
# Downloading mlflow-2.17.2-py3-none-any.whl (26.7 MB)
#    ---------------------------------------- 0.0/26.7 MB ? eta -:--:--
#    ---------------------------------------- 0.2/26.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.7 MB 3.5 MB/s eta 0:00:08
#     --------------------------------------- 0.4/26.7 MB 3.1 MB/s eta 0:00:09
#     --------------------------------------- 0.5/26.7 MB 2.8 MB/s eta 0:00:10
#     --------------------------------------- 0.7/26.7 MB 3.0 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/26.7 MB 2.8 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/26.7 MB 2.9 MB/s eta 0:00:09
#    - -------------------------------------- 1.1/26.7 MB 3.0 MB/s eta 0:00:09
#    - -------------------------------------- 1.3/26.7 MB 3.0 MB/s eta 0:00:09
#    -- ------------------------------------- 1.4/26.7 MB 3.1 MB/s eta 0:00:09
#    -- ------------------------------------- 1.6/26.7 MB 3.1 MB/s eta 0:00:09
#    -- ------------------------------------- 1.8/26.7 MB 3.2 MB/s eta 0:00:08
#    -- ------------------------------------- 1.9/26.7 MB 3.2 MB/s eta 0:00:08
#    --- ------------------------------------ 2.2/26.7 MB 3.2 MB/s eta 0:00:08
#    --- ------------------------------------ 2.4/26.7 MB 3.4 MB/s eta 0:00:08
#    --- ------------------------------------ 2.6/26.7 MB 3.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.8/26.7 MB 3.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.1/26.7 MB 3.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.3/26.7 MB 3.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.6/26.7 MB 3.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.8/26.7 MB 3.8 MB/s eta 0:00:06
#    ------ --------------------------------- 4.1/26.7 MB 3.9 MB/s eta 0:00:06
#    ------ --------------------------------- 4.4/26.7 MB 4.0 MB/s eta 0:00:06
#    ------ --------------------------------- 4.6/26.7 MB 4.1 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/26.7 MB 4.2 MB/s eta 0:00:06
#    ------- -------------------------------- 5.3/26.7 MB 4.3 MB/s eta 0:00:05
#    -------- ------------------------------- 5.6/26.7 MB 4.4 MB/s eta 0:00:05
#    -------- ------------------------------- 6.0/26.7 MB 4.4 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/26.7 MB 4.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.7/26.7 MB 4.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 7.1/26.7 MB 4.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.5/26.7 MB 4.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.9/26.7 MB 5.0 MB/s eta 0:00:04
#    ------------ --------------------------- 8.4/26.7 MB 5.1 MB/s eta 0:00:04
#    ------------- -------------------------- 8.9/26.7 MB 5.3 MB/s eta 0:00:04
#    -------------- ------------------------- 9.5/26.7 MB 5.5 MB/s eta 0:00:04
#    -------------- ------------------------- 9.9/26.7 MB 5.6 MB/s eta 0:00:04
#    --------------- ------------------------ 10.4/26.7 MB 5.6 MB/s eta 0:00:03
#    --------------- ------------------------ 10.6/26.7 MB 6.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 11.1/26.7 MB 6.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.6/26.7 MB 6.7 MB/s eta 0:00:03
#    ------------------ --------------------- 12.1/26.7 MB 7.3 MB/s eta 0:00:03
#    ------------------- -------------------- 12.8/26.7 MB 7.7 MB/s eta 0:00:02
#    ------------------- -------------------- 13.3/26.7 MB 8.3 MB/s eta 0:00:02
#    -------------------- ------------------- 14.0/26.7 MB 8.7 MB/s eta 0:00:02
#    --------------------- ------------------ 14.4/26.7 MB 9.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.1/26.7 MB 9.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.7/26.7 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 16.3/26.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 16.4/26.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------ --------------- 16.6/26.7 MB 9.6 MB/s eta 0:00:02
#    ------------------------- -------------- 17.0/26.7 MB 9.8 MB/s eta 0:00:02
#    ------------------------- -------------- 17.4/26.7 MB 9.8 MB/s eta 0:00:01
#    -------------------------- ------------- 17.4/26.7 MB 9.2 MB/s eta 0:00:02
#    -------------------------- ------------- 17.7/26.7 MB 9.1 MB/s eta 0:00:01
#    --------------------------- ------------ 18.4/26.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.1/26.7 MB 9.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.8/26.7 MB 9.8 MB/s eta 0:00:01
#    ------------------------------ --------- 20.3/26.7 MB 9.9 MB/s eta 0:00:01
#    ------------------------------- -------- 20.9/26.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------------- -------- 21.2/26.7 MB 10.1 MB/s eta 0:00:01
#    -------------------------------- ------- 21.7/26.7 MB 10.1 MB/s eta 0:00:01
#    --------------------------------- ------ 22.6/26.7 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 23.3/26.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------------------ --- 24.2/26.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 24.6/26.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 25.0/26.7 MB 10.4 MB/s eta 0:00:01
#    -------------------------------------- - 25.8/26.7 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  26.5/26.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  26.7/26.7 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 26.7/26.7 MB 10.4 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.17.2-py3-none-any.whl (5.7 MB)
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.7 MB 16.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.5/5.7 MB 16.3 MB/s eta 0:00:01
#    --------------- ------------------------ 2.2/5.7 MB 15.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.0/5.7 MB 15.7 MB/s eta 0:00:01
#    ------------------------- -------------- 3.6/5.7 MB 15.5 MB/s eta 0:00:01
#    ------------------------------- -------- 4.4/5.7 MB 15.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.2/5.7 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.7 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.7/5.7 MB 13.4 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.5 kB ? eta -:--:--
#    ---------------------------------------- 233.5/233.5 kB 4.7 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.8 kB ? eta -:--:--
#    ---------------------------------------- 147.8/147.8 kB 9.2 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ---------------------------------------- 0.0/114.9 kB ? eta -:--:--
#    ---------------------------------------- 114.9/114.9 kB 7.0 MB/s eta 0:00:00
# Downloading waitress-3.0.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.7 kB ? eta -:--:--
#    ---------------------------------------- 56.7/56.7 kB 2.9 MB/s eta 0:00:00
# Downloading databricks_sdk-0.36.0-py3-none-any.whl (569 kB)
#    ---------------------------------------- 0.0/569.1 kB ? eta -:--:--
#    --------------------------------------- 569.1/569.1 kB 11.9 MB/s eta 0:00:00
# Downloading graphql_core-3.2.5-py3-none-any.whl (203 kB)
#    ---------------------------------------- 0.0/203.2 kB ? eta -:--:--
#    ---------------------------------------- 203.2/203.2 kB 6.0 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.3 kB ? eta -:--:--
#    ---------------------------------------- 64.3/64.3 kB 1.7 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
#    ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#    ---------------------------------------- 118.7/118.7 kB 3.4 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
#    ---------------------------------------- 0.0/159.2 kB ? eta -:--:--
#    ---------------------------------------- 159.2/159.2 kB 4.8 MB/s eta 0:00:00
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.2 kB ? eta -:--:--
#    ---------------------------------------- 44.2/44.2 kB 1.1 MB/s eta 0:00:00
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
#    ---------------------------------------- 0.0/209.5 kB ? eta -:--:--
#    ---------------------------------------- 209.5/209.5 kB 6.4 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Installing collected packages: waitress, sqlparse, rsa, Mako, graphql-core, deprecated, opentelemetry-api, graphql-relay, google-auth, docker, alembic, opentelemetry-semantic-conventions, graphene, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
# Successfully installed Mako-1.3.6 alembic-1.14.0 databricks-sdk-0.36.0 deprecated-1.2.14 docker-7.1.0 google-auth-2.36.0 graphene-3.4.3 graphql-core-3.2.5 graphql-relay-3.2.0 mlflow-2.17.2 mlflow-skinny-2.17.2 opentelemetry-api-1.28.1 opentelemetry-sdk-1.28.1 opentelemetry-semantic-conventions-0.49b1 rsa-4.9 sqlparse-0.5.1 waitress-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import mlflow3
import mlflow.sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_validate

# IrisDataProcessor 
class IrisDataProcessor:
    def __init__(self):
        
        self.iris_data = load_iris()
        
        self.data = pd.DataFrame(data=self.iris_data.data, columns=self.iris_data.feature_names)
        self.data['target'] = self.iris_data.target  # Add target column
        
        # StandardScaler for feature scaling
        self.scaler = StandardScaler()
        self.train_data = None
        self.test_data = None
        self.experiment_log = []

    def prepare_data(self, test_size=0.2, random_state=42):
       
        # Separate features (X) and target (y)
        X = self.data.drop(columns=['target'])
        y = self.data['target']
        
        # Split data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
        
        # Feature scaling
        X_train_scaled = self.scaler.fit_transform(X_train)
        X_test_scaled = self.scaler.transform(X_test)
        
        # Store the train and test data
        self.train_data = (X_train_scaled, y_train)
        self.test_data = (X_test_scaled, y_test)
        
        # Log experiment details 
        experiment_details = {
            "test_size": test_size,
            "random_state": random_state,
            "scaler_mean": self.scaler.mean_.tolist(),
            "scaler_variance": self.scaler.var_.tolist()
        }
        self.experiment_log.append(experiment_details)

    def get_feature_stats(self):
       
        stats = self.data.describe().T[['mean', 'std', 'min', 'max']]
        return stats

# IrisExperiment Class
class IrisExperiment:
    def __init__(self, data_processor):
       
        self.data_processor = data_processor
        self.models = {
            "Logistic Regression": LogisticRegression(max_iter=200),
            "Random Forest": RandomForestClassifier(n_estimators=100)
        }
        self.metrics = {
            "accuracy": make_scorer(accuracy_score),
            "precision": make_scorer(precision_score, average="weighted"),
            "recall": make_scorer(recall_score, average="weighted")
        }

    def run_experiment(self):
       

        self.data_processor.prepare_data()
        X_train, y_train = self.data_processor.train_data

        # Iterate over each model to conduct experiments
        for model_name, model in self.models.items():
            with mlflow.start_run(run_name=model_name):
                # Cross-validation
                results = cross_validate(model, X_train, y_train, cv=5, scoring=self.metrics, return_train_score=False)

                # Average metrics across folds
                accuracy = np.mean(results["test_accuracy"])
                precision = np.mean(results["test_precision"])
                recall = np.mean(results["test_recall"])

                # Results
                self.log_results(model_name, accuracy, precision, recall)

                print(f"{model_name}: Accuracy={accuracy:.4f}, Precision={precision:.4f}, Recall={recall:.4f}")

    def log_results(self, model_name, accuracy, precision, recall):
        
        # Log model parameters
        mlflow.log_param("model_name", model_name)

        # Log metrics
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("recall", recall)

        mlflow.sklearn.log_model(self.models[model_name], model_name)

data_processor = IrisDataProcessor()
experiment = IrisExperiment(data_processor)
experiment.run_experiment()
# Out:
# 2024/11/12 12:54:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Logistic Regression: Accuracy=0.9583, Precision=0.9669, Recall=0.9583
# 2024/11/12 12:54:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Random Forest: Accuracy=0.9500, Precision=0.9595, Recall=0.9500
